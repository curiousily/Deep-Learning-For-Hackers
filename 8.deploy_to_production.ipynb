# %%
# !pip install tensorflow-gpu
# !pip install gdown
# Out:
# Collecting tensorflow-gpu
#   Downloading https://files.pythonhosted.org/packages/25/44/47f0722aea081697143fbcf5d2aa60d1aee4aaacb5869aee2b568974777b/tensorflow_gpu-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (380.8MB)
#      |████████████████████████████████| 380.8MB 45kB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.17.3)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.0.8)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.11.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.1.7)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.15.0)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/9b/a6/e8ffa4e2ddb216449d34cfcb825ebb38206bee5c4553d69e7bc8bc2c5d64/tensorboard-2.0.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 38.9MB/s
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.33.6)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 46.4MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu) (41.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu) (0.16.0)
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 2.0.0 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
# Successfully installed tensorboard-2.0.0 tensorflow-estimator-2.0.1 tensorflow-gpu-2.0.0
# Requirement already satisfied: gdown in /usr/local/lib/python3.6/dist-packages (3.6.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gdown) (4.28.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gdown) (1.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gdown) (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (3.0.4)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
import joblib

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 16, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
# !gdown --id 1aRXGcJlIkuC6uj1iLqzi9DQQS-3GPwM_ --output airbnb_nyc.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1aRXGcJlIkuC6uj1iLqzi9DQQS-3GPwM_
# To: /content/airbnb_nyc.csv
# 7.08MB [00:00, 43.1MB/s]

# %%
df = pd.read_csv('airbnb_nyc.csv')

# %% [markdown]
# # Exploration

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
sns.distplot(df.price);

# %%
sns.distplot(np.log1p(df.price));

# %%
sns.countplot(x='neighbourhood_group', data=df);

# %%
sns.countplot(x='room_type', data=df);

# %%
sns.distplot(df.minimum_nights);

# %%
sns.distplot(df.number_of_reviews);

# %%
corr_matrix = df.corr()

# %%
price_corr = corr_matrix['price']
price_corr.iloc[price_corr.abs().argsort()]
# Out:
# id                                0.010619
# host_id                           0.015309
# reviews_per_month                -0.030608
# latitude                          0.033939
# minimum_nights                    0.042799
# number_of_reviews                -0.047954
# calculated_host_listings_count    0.057472
# availability_365                  0.081829
# longitude                        -0.150019
# price                             1.000000
# Name: price, dtype: float64

# %%
palette = sns.diverging_palette(20, 220, n=256)
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap=palette, vmax=.3, center=0,
            square=True, linewidths=.5);

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Missing data?

# %%
missing = df.isnull().sum()
missing[missing > 0].sort_values(ascending=False)
# Out:
# reviews_per_month    10052
# last_review          10052
# host_name               21
# name                    16
# dtype: int64

# %% [markdown]
# ## Remove unused columns!

# %%
df = df.drop(['id', 'name', 'host_id', 'host_name', 'reviews_per_month', 'last_review', 'neighbourhood'], axis=1)

# %%
missing = df.isnull().sum()
missing[missing > 0].sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %%
df.columns
# Out:
# Index(['neighbourhood_group', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.head()
# Out:
#   neighbourhood_group  ...  availability_365
# 0            Brooklyn  ...               365
# 1           Manhattan  ...               355
# 2           Manhattan  ...               365
# 3            Brooklyn  ...               194
# 4           Manhattan  ...                 0
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Predict log1p

# %%
X = df.drop('price', axis=1)
y = np.log1p(df.price.values)

# %% [markdown]
# ## Feature scaling and One-hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder

data = [['Manhattan'], ['Brooklyn']]

OneHotEncoder(sparse=False).fit_transform(data)
# Out:
# array([[0., 1.],
#        [1., 0.]])

# %%
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import make_column_transformer

transformer = make_column_transformer(
    (MinMaxScaler(), ['latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365']),
    (OneHotEncoder(handle_unknown="ignore"), ['neighbourhood_group', 'room_type'])
)

# %%
transformer.fit(X)
# Out:
# ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('minmaxscaler',
#                                  MinMaxScaler(copy=True, feature_range=(0, 1)),
#                                  ['latitude', 'longitude', 'minimum_nights',
#                                   'number_of_reviews',
#                                   'calculated_host_listings_count',
#                                   'availability_365']),
#                                 ('onehotencoder',
#                                  OneHotEncoder(categorical_features=None,
#                                                categories=None, drop=None,
#                                                dtype=<class 'numpy.float64'>,
#                                                handle_unknown='ignore',
#                                                n_values=None, sparse=True),
#                                  ['neighbourhood_group', 'room_type'])],
#                   verbose=False)

# %%
X = transformer.transform(X)

# %% [markdown]
# ## Split the training and test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED)

# %%
X_train.shape
# Out:
# (39116, 14)

# %% [markdown]
# # Modeling

# %%
def plot_mse(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('MSE')
  plt.plot(hist['epoch'], hist['mse'],
            label='Train MSE')
  plt.plot(hist['epoch'], hist['val_mse'],
            label = 'Val MSE')
  plt.legend()
  plt.show()

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(units=64, activation="relu", input_shape=[X_train.shape[1]]))
model.add(keras.layers.Dropout(rate=0.3))
model.add(keras.layers.Dense(units=32, activation="relu"))
model.add(keras.layers.Dropout(rate=0.5))

model.add(keras.layers.Dense(1))

model.compile(
    optimizer=keras.optimizers.Adam(0.0001),
    loss = 'mse', 
    metrics = ['mse'])

BATCH_SIZE = 32

early_stop = keras.callbacks.EarlyStopping(
  monitor='val_mse',
  mode="min",
  patience=10
)

history = model.fit(
  x=X_train,
  y=y_train,
  shuffle=True,
  epochs=100,
  validation_split=0.2,
  batch_size=BATCH_SIZE,
  callbacks=[early_stop]
)

plot_mse(history)
# Out:
# Train on 31292 samples, validate on 7824 samples
# Epoch 1/100
# 31292/31292 [==============================] - 6s 181us/sample - loss: 8.7079 - mse: 8.7079 - val_loss: 0.5533 - val_mse: 0.5533
# Epoch 2/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 2.3689 - mse: 2.3689 - val_loss: 0.4569 - val_mse: 0.4569
# Epoch 3/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 2.1296 - mse: 2.1296 - val_loss: 0.4418 - val_mse: 0.4418
# Epoch 4/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 2.0007 - mse: 2.0007 - val_loss: 0.4275 - val_mse: 0.4275
# Epoch 5/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 1.9427 - mse: 1.9427 - val_loss: 0.4257 - val_mse: 0.4257
# Epoch 6/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 1.8758 - mse: 1.8758 - val_loss: 0.4258 - val_mse: 0.4258
# Epoch 7/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 1.8158 - mse: 1.8158 - val_loss: 0.3888 - val_mse: 0.3888
# Epoch 8/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 1.6837 - mse: 1.6837 - val_loss: 0.3625 - val_mse: 0.3625
# Epoch 9/100
# 31292/31292 [==============================] - 4s 138us/sample - loss: 1.6104 - mse: 1.6104 - val_loss: 0.3858 - val_mse: 0.3858
# Epoch 10/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 1.5451 - mse: 1.5451 - val_loss: 0.3899 - val_mse: 0.3899
# Epoch 11/100
# 31292/31292 [==============================] - 4s 139us/sample - loss: 1.4726 - mse: 1.4726 - val_loss: 0.3143 - val_mse: 0.3143
# Epoch 12/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 1.4200 - mse: 1.4200 - val_loss: 0.3296 - val_mse: 0.3296
# Epoch 13/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 1.3764 - mse: 1.3764 - val_loss: 0.3677 - val_mse: 0.3677
# Epoch 14/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 1.3316 - mse: 1.3316 - val_loss: 0.3473 - val_mse: 0.3473
# Epoch 15/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 1.2729 - mse: 1.2729 - val_loss: 0.3307 - val_mse: 0.3307
# Epoch 16/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 1.2420 - mse: 1.2420 - val_loss: 0.3226 - val_mse: 0.3226
# Epoch 17/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 1.1660 - mse: 1.1660 - val_loss: 0.3241 - val_mse: 0.3241
# Epoch 18/100
# 31292/31292 [==============================] - 4s 140us/sample - loss: 1.0746 - mse: 1.0746 - val_loss: 0.3197 - val_mse: 0.3197
# Epoch 19/100
# 31292/31292 [==============================] - 5s 146us/sample - loss: 1.0228 - mse: 1.0228 - val_loss: 0.2883 - val_mse: 0.2883
# Epoch 20/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.9810 - mse: 0.9810 - val_loss: 0.3102 - val_mse: 0.3102
# Epoch 21/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.9548 - mse: 0.9548 - val_loss: 0.3103 - val_mse: 0.3103
# Epoch 22/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 0.9163 - mse: 0.9163 - val_loss: 0.3103 - val_mse: 0.3103
# Epoch 23/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.8813 - mse: 0.8813 - val_loss: 0.2961 - val_mse: 0.2961
# Epoch 24/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 0.8493 - mse: 0.8493 - val_loss: 0.3075 - val_mse: 0.3075
# Epoch 25/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 0.8289 - mse: 0.8289 - val_loss: 0.2805 - val_mse: 0.2805
# Epoch 26/100
# 31292/31292 [==============================] - 4s 143us/sample - loss: 0.7931 - mse: 0.7931 - val_loss: 0.2980 - val_mse: 0.2980
# Epoch 27/100
# 31292/31292 [==============================] - 5s 148us/sample - loss: 0.7599 - mse: 0.7599 - val_loss: 0.2825 - val_mse: 0.2825
# Epoch 28/100
# 31292/31292 [==============================] - 4s 140us/sample - loss: 0.7442 - mse: 0.7442 - val_loss: 0.2762 - val_mse: 0.2762
# Epoch 29/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.7204 - mse: 0.7204 - val_loss: 0.2984 - val_mse: 0.2984
# Epoch 30/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.6912 - mse: 0.6912 - val_loss: 0.2750 - val_mse: 0.2750
# Epoch 31/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.6574 - mse: 0.6574 - val_loss: 0.2773 - val_mse: 0.2773
# Epoch 32/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 0.6376 - mse: 0.6376 - val_loss: 0.2754 - val_mse: 0.2754
# Epoch 33/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 0.6188 - mse: 0.6188 - val_loss: 0.2689 - val_mse: 0.2689
# Epoch 34/100
# 31292/31292 [==============================] - 4s 130us/sample - loss: 0.5944 - mse: 0.5944 - val_loss: 0.2733 - val_mse: 0.2733
# Epoch 35/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.5769 - mse: 0.5769 - val_loss: 0.2699 - val_mse: 0.2699
# Epoch 36/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.5567 - mse: 0.5567 - val_loss: 0.2687 - val_mse: 0.2687
# Epoch 37/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.5446 - mse: 0.5446 - val_loss: 0.2737 - val_mse: 0.2737
# Epoch 38/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 0.5215 - mse: 0.5215 - val_loss: 0.2693 - val_mse: 0.2693
# Epoch 39/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.5096 - mse: 0.5096 - val_loss: 0.2647 - val_mse: 0.2647
# Epoch 40/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 0.4977 - mse: 0.4977 - val_loss: 0.2753 - val_mse: 0.2753
# Epoch 41/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.4800 - mse: 0.4800 - val_loss: 0.2656 - val_mse: 0.2656
# Epoch 42/100
# 31292/31292 [==============================] - 4s 138us/sample - loss: 0.4739 - mse: 0.4739 - val_loss: 0.2611 - val_mse: 0.2611
# Epoch 43/100
# 31292/31292 [==============================] - 4s 140us/sample - loss: 0.4549 - mse: 0.4549 - val_loss: 0.2631 - val_mse: 0.2631
# Epoch 44/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 0.4442 - mse: 0.4442 - val_loss: 0.2625 - val_mse: 0.2625
# Epoch 45/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.4253 - mse: 0.4253 - val_loss: 0.2568 - val_mse: 0.2568
# Epoch 46/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.4152 - mse: 0.4152 - val_loss: 0.2591 - val_mse: 0.2591
# Epoch 47/100
# 31292/31292 [==============================] - 4s 132us/sample - loss: 0.4107 - mse: 0.4107 - val_loss: 0.2609 - val_mse: 0.2609
# Epoch 48/100
# 31292/31292 [==============================] - 6s 177us/sample - loss: 0.3931 - mse: 0.3931 - val_loss: 0.2573 - val_mse: 0.2573
# Epoch 49/100
# 31292/31292 [==============================] - 5s 146us/sample - loss: 0.3858 - mse: 0.3858 - val_loss: 0.2579 - val_mse: 0.2579
# Epoch 50/100
# 31292/31292 [==============================] - 4s 140us/sample - loss: 0.3730 - mse: 0.3730 - val_loss: 0.2531 - val_mse: 0.2531
# Epoch 51/100
# 31292/31292 [==============================] - 5s 146us/sample - loss: 0.3657 - mse: 0.3657 - val_loss: 0.2527 - val_mse: 0.2527
# Epoch 52/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.3617 - mse: 0.3617 - val_loss: 0.2560 - val_mse: 0.2560
# Epoch 53/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.3513 - mse: 0.3513 - val_loss: 0.2562 - val_mse: 0.2562
# Epoch 54/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.3468 - mse: 0.3468 - val_loss: 0.2524 - val_mse: 0.2524
# Epoch 55/100
# 31292/31292 [==============================] - 5s 152us/sample - loss: 0.3385 - mse: 0.3385 - val_loss: 0.2512 - val_mse: 0.2512
# Epoch 56/100
# 31292/31292 [==============================] - 5s 145us/sample - loss: 0.3326 - mse: 0.3326 - val_loss: 0.2532 - val_mse: 0.2532
# Epoch 57/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 0.3258 - mse: 0.3258 - val_loss: 0.2507 - val_mse: 0.2507
# Epoch 58/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.3220 - mse: 0.3220 - val_loss: 0.2527 - val_mse: 0.2527
# Epoch 59/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 0.3130 - mse: 0.3130 - val_loss: 0.2523 - val_mse: 0.2523
# Epoch 60/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.3126 - mse: 0.3126 - val_loss: 0.2509 - val_mse: 0.2509
# Epoch 61/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.3031 - mse: 0.3031 - val_loss: 0.2507 - val_mse: 0.2507
# Epoch 62/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2980 - mse: 0.2980 - val_loss: 0.2477 - val_mse: 0.2477
# Epoch 63/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 0.2968 - mse: 0.2968 - val_loss: 0.2492 - val_mse: 0.2492
# Epoch 64/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 0.2952 - mse: 0.2952 - val_loss: 0.2475 - val_mse: 0.2475
# Epoch 65/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.2879 - mse: 0.2879 - val_loss: 0.2464 - val_mse: 0.2464
# Epoch 66/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.2838 - mse: 0.2838 - val_loss: 0.2482 - val_mse: 0.2482
# Epoch 67/100
# 31292/31292 [==============================] - 5s 149us/sample - loss: 0.2826 - mse: 0.2826 - val_loss: 0.2475 - val_mse: 0.2475
# Epoch 68/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.2809 - mse: 0.2809 - val_loss: 0.2449 - val_mse: 0.2449
# Epoch 69/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 0.2776 - mse: 0.2776 - val_loss: 0.2473 - val_mse: 0.2473
# Epoch 70/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 0.2743 - mse: 0.2743 - val_loss: 0.2424 - val_mse: 0.2424
# Epoch 71/100
# 31292/31292 [==============================] - 4s 138us/sample - loss: 0.2749 - mse: 0.2749 - val_loss: 0.2427 - val_mse: 0.2427
# Epoch 72/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2711 - mse: 0.2711 - val_loss: 0.2472 - val_mse: 0.2472
# Epoch 73/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2663 - mse: 0.2663 - val_loss: 0.2438 - val_mse: 0.2438
# Epoch 74/100
# 31292/31292 [==============================] - 4s 132us/sample - loss: 0.2660 - mse: 0.2660 - val_loss: 0.2427 - val_mse: 0.2427
# Epoch 75/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2653 - mse: 0.2653 - val_loss: 0.2428 - val_mse: 0.2428
# Epoch 76/100
# 31292/31292 [==============================] - 4s 131us/sample - loss: 0.2644 - mse: 0.2644 - val_loss: 0.2428 - val_mse: 0.2428
# Epoch 77/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2632 - mse: 0.2632 - val_loss: 0.2431 - val_mse: 0.2431
# Epoch 78/100
# 31292/31292 [==============================] - 4s 132us/sample - loss: 0.2613 - mse: 0.2613 - val_loss: 0.2416 - val_mse: 0.2416
# Epoch 79/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.2584 - mse: 0.2584 - val_loss: 0.2406 - val_mse: 0.2406
# Epoch 80/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2581 - mse: 0.2581 - val_loss: 0.2408 - val_mse: 0.2408
# Epoch 81/100
# 31292/31292 [==============================] - 4s 136us/sample - loss: 0.2562 - mse: 0.2562 - val_loss: 0.2398 - val_mse: 0.2398
# Epoch 82/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.2571 - mse: 0.2571 - val_loss: 0.2408 - val_mse: 0.2408
# Epoch 83/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2525 - mse: 0.2525 - val_loss: 0.2389 - val_mse: 0.2389
# Epoch 84/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2538 - mse: 0.2538 - val_loss: 0.2398 - val_mse: 0.2398
# Epoch 85/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2527 - mse: 0.2527 - val_loss: 0.2400 - val_mse: 0.2400
# Epoch 86/100
# 31292/31292 [==============================] - 4s 132us/sample - loss: 0.2540 - mse: 0.2540 - val_loss: 0.2393 - val_mse: 0.2393
# Epoch 87/100
# 31292/31292 [==============================] - 4s 133us/sample - loss: 0.2533 - mse: 0.2533 - val_loss: 0.2379 - val_mse: 0.2379
# Epoch 88/100
# 31292/31292 [==============================] - 4s 132us/sample - loss: 0.2512 - mse: 0.2512 - val_loss: 0.2391 - val_mse: 0.2391
# Epoch 89/100
# 31292/31292 [==============================] - 4s 134us/sample - loss: 0.2497 - mse: 0.2497 - val_loss: 0.2387 - val_mse: 0.2387
# Epoch 90/100
# 31292/31292 [==============================] - 5s 146us/sample - loss: 0.2517 - mse: 0.2517 - val_loss: 0.2384 - val_mse: 0.2384
# Epoch 91/100
# 31292/31292 [==============================] - 4s 139us/sample - loss: 0.2512 - mse: 0.2512 - val_loss: 0.2389 - val_mse: 0.2389
# Epoch 92/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.2494 - mse: 0.2494 - val_loss: 0.2386 - val_mse: 0.2386
# Epoch 93/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 0.2487 - mse: 0.2487 - val_loss: 0.2368 - val_mse: 0.2368
# Epoch 94/100
# 31292/31292 [==============================] - 5s 160us/sample - loss: 0.2490 - mse: 0.2490 - val_loss: 0.2379 - val_mse: 0.2379
# Epoch 95/100
# 31292/31292 [==============================] - 4s 137us/sample - loss: 0.2486 - mse: 0.2486 - val_loss: 0.2391 - val_mse: 0.2391
# Epoch 96/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 0.2490 - mse: 0.2490 - val_loss: 0.2395 - val_mse: 0.2395
# Epoch 97/100
# 31292/31292 [==============================] - 4s 135us/sample - loss: 0.2461 - mse: 0.2461 - val_loss: 0.2367 - val_mse: 0.2367
# Epoch 98/100
# 31292/31292 [==============================] - 4s 138us/sample - loss: 0.2476 - mse: 0.2476 - val_loss: 0.2382 - val_mse: 0.2382
# Epoch 99/100
# 31292/31292 [==============================] - 5s 147us/sample - loss: 0.2467 - mse: 0.2467 - val_loss: 0.2389 - val_mse: 0.2389
# Epoch 100/100
# 31292/31292 [==============================] - 4s 143us/sample - loss: 0.2470 - mse: 0.2470 - val_loss: 0.2375 - val_mse: 0.2375

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt
from sklearn.metrics import r2_score

# %%
y_pred = model.predict(X_test)

# %%
f'MSE {mean_squared_error(y_test, y_pred)}'
# Out:
# 'MSE 0.21402013564287092'

# %%
f'MAE {mean_absolute_error(y_test, y_pred)}'
# Out:
# 'MAE 0.33315857508453867'

# %%
f'RMSE {np.sqrt(mean_squared_error(y_test, y_pred))}'
# Out:
# 'RMSE 0.4626231032307735'

# %%
f'R2 {r2_score(y_test, y_pred)}'
# Out:
# 'R2 0.5476099980350737'

# %% [markdown]
# # Saving

# %%
joblib.dump(transformer, "data_transformer.joblib")
model.save("price_prediction_model.h5")

# %%
from google.colab import files

# %%
files.download("data_transformer.joblib")
files.download("price_prediction_model.h5")
